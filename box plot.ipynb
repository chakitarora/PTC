# %%
import seaborn as sns
import matplotlib as plt
df = sns.load_dataset('tips')
 
# Grouped boxplot
sns.boxplot(x="day", y="total_bill", hue="smoker", data=df, palette="Set1")
#sns.plt.show()

# %%
import pandas as pd
name='THCA_valid_age65_90'
df=pd.read_csv('/Users/macbook/Desktop/THCA/validation/'+str(name)+'.csv')
df.columns=['HR','C']
df['ss']='90%'
df['model']='hybrid_age_65'

df.to_csv('/Users/macbook/Desktop/THCA/validation/'+str(name)+'_new.csv',index=False)

# %%
import os
import glob
import pandas as pd
os.chdir("/Users/macbook/Desktop/THCA/validation/boxplot/")

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#combined_csv = pd.concat([pd.read_csv(f).rename(columns={'Gene': str.split(f,'_')[0]}) for f in all_filenames ],axis=1)
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ],axis=0)

combined_csv.to_csv('/Users/macbook/Desktop/THCA/validation/THCA_boxplot.csv',index=None)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#df = sns.load_dataset('tips')
 
# Grouped boxplot
sns.boxplot(x="Sampling size", y="Concordance (C)", hue="Model", data=combined_csv, palette="Paired",whis=1.5)
#sns.plt.show()
plt.savefig("/Users/macbook/Desktop/THCA/validation/THCA_boxplot_C.png",dpi=300)

# %%
combined_csv.columns=['Hazard Ratio (HR)', 'Concordance (C)', 'Sampling size', 'Model']
